# %%
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
import pylab as pl
from itertools import cycle

iris = load_iris()

samples, features = iris.data.shape
print('Número de dados: ', samples)
print('Número de colunas / recursos: ', features)
print(list(iris.target_names))
# Out:
# Número de dados:  150
# Número de colunas / recursos:  4
# [np.str_('setosa'), np.str_('versicolor'), np.str_('virginica')]

# %%
x = iris.data
pca = PCA(n_components=2, whiten=True).fit(x)
x_pca = pca.transform(x)
print(x_pca.shape)
print(pca.components_)
# Out:
# (150, 2)
# [[ 0.36138659 -0.08452251  0.85667061  0.3582892 ]
#  [ 0.65658877  0.73016143 -0.17337266 -0.07548102]]

# %%
print(pca.explained_variance_ratio_)
print(sum(pca.explained_variance_ratio_))
# Out:
# [0.92461872 0.05306648]
# 0.9776852063187977

# %%
colors = cycle('rgb')
target_ids = range(len(iris.target_names))
pl.figure()

for i, c, label in zip(target_ids, colors, iris.target_names):
    pl.scatter(x_pca[iris.target == i, 0], x_pca[iris.target == i, 1], c=c, label=label)

pl.legend()
pl.show()

# %% [markdown]
# ## Atividade ##
# Testar o PCA para transformar os dados em apenas um só componente
